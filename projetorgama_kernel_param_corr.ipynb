# %% [markdown]
# ## Setup

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import filter_toolbox
from scipy.signal import find_peaks
import Interface as mi
from typing import List, Callable
import numpy as np 
from GamaProjectorPipeline import GamaProjectorPipeline as model_pipeline
from scipy.signal import find_peaks 
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import cv2  # OpenCV para carregar a imagem
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy.signal import find_peaks 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
filter_intensity = 0.2

# %% [markdown]
# ## T1

# %%
img_path = r"data\sdss\sdss_image_180.171408773627_0.35639930317447.jpg"

# %%
# Carregar a imagem
img = mpimg.imread(img_path)

# Criar uma nova figura
plt.figure(figsize=(5, 5))  # O argumento figsize define o tamanho da figura

# Exibir a imagem
plt.imshow(img)

# Remover os eixos
plt.axis('off')

# Mostrar a figura
plt.show()

# %%
def generate_kernel_params(shape: int) -> List[mi.KernelParam]:
        """
        Gera uma lista de parâmetros de kernel com combinações de `size` e `sigma` 
        que respeitam a equação do projetor gama.
        
        Parâmetros:
        - max_size: tamanho máximo permitido para o kernel baseado no tamanho da imagem.

        Retorna:
        - Uma lista de `mi.KernelParam` com todas as combinações válidas de `size` e `sigma`.
        """
        kernel_params = []
        M, N = shape
        for K_s in range(3, min(M, N)):# Tamanhos de kernel ímpares
            for sigma in range(1, int(2 * K_s + 3)):
                kernel_params.append(mi.KernelParam(size=K_s, sigma=sigma))
        return kernel_params

# %%
img.shape[0:2]
# Out:
# (120, 120)

# %%
kernel_param = generate_kernel_params(img.shape[0:2])

kernel_param
# Out:
# [KernelParam(size=3, sigma=1.0),
#  KernelParam(size=3, sigma=2.0),
#  KernelParam(size=3, sigma=3.0),
#  KernelParam(size=3, sigma=4.0),
#  KernelParam(size=3, sigma=5.0),
#  KernelParam(size=3, sigma=6.0),
#  KernelParam(size=3, sigma=7.0),
#  KernelParam(size=3, sigma=8.0),
#  KernelParam(size=4, sigma=1.0),
#  KernelParam(size=4, sigma=2.0),
#  KernelParam(size=4, sigma=3.0),
#  KernelParam(size=4, sigma=4.0),
#  KernelParam(size=4, sigma=5.0),
#  KernelParam(size=4, sigma=6.0),
#  KernelParam(size=4, sigma=7.0),
#  KernelParam(size=4, sigma=8.0),
#  KernelParam(size=4, sigma=9.0),
#  KernelParam(size=4, sigma=10.0),
#  KernelParam(size=5, sigma=1.0),
#  KernelParam(size=5, sigma=2.0),
#  KernelParam(size=5, sigma=3.0),
#  KernelParam(size=5, sigma=4.0),
#  KernelParam(size=5, sigma=5.0),
#  KernelParam(size=5, sigma=6.0),
#  KernelParam(size=5, sigma=7.0),
#  KernelParam(size=5, sigma=8.0),
#  KernelParam(size=5, sigma=9.0),
#  KernelParam(size=5, sigma=10.0),
#  KernelParam(size=5, sigma=11.0),
#  KernelParam(size=5, sigma=12.0),
#  KernelParam(size=6, sigma=1.0),
#  KernelParam(size=6, sigma=2.0),
#  KernelParam(size=6, sigma=3.0),
#  KernelParam(size=6, sigma=4.0),
#  KernelParam(size=6, sigma=5.0),
#  KernelParam(size=6, sigma=6.0),
#  KernelParam(size=6, sigma=7.0),
#  KernelParam(size=6, sigma=8.0),
#  KernelParam(size=6, sigma=9.0),
#  KernelParam(size=6, sigma=10.0),
#  KernelParam(size=6, sigma=11.0),
#  KernelParam(size=6, sigma=12.0),
#  KernelParam(size=6, sigma=13.0),
#  KernelParam(size=6, sigma=14.0),
#  KernelParam(size=7, sigma=1.0),
#  KernelParam(size=7, sigma=2.0),
#  KernelParam(size=7, sigma=3.0),
#  KernelParam(size=7, sigma=4.0),
#  KernelParam(size=7, sigma=5.0),
#  KernelParam(size=7, sigma=6.0),
#  KernelParam(size=7, sigma=7.0),
#  KernelParam(size=7, sigma=8.0),
#  KernelParam(size=7, sigma=9.0),
#  KernelParam(size=7, sigma=10.0),
#  KernelParam(size=7, sigma=11.0),
#  KernelParam(size=7, sigma=12.0),
#  KernelParam(size=7, sigma=13.0),
#  KernelParam(size=7, sigma=14.0),
#  KernelParam(size=7, sigma=15.0),
#  KernelParam(size=7, sigma=16.0),
#  KernelParam(size=8, sigma=1.0),
#  KernelParam(size=8, sigma=2.0),
#  KernelParam(size=8, sigma=3.0),
#  KernelParam(size=8, sigma=4.0),
#  KernelParam(size=8, sigma=5.0),
#  KernelParam(size=8, sigma=6.0),
#  KernelParam(size=8, sigma=7.0),
#  KernelParam(size=8, sigma=8.0),
#  KernelParam(size=8, sigma=9.0),
#  KernelParam(size=8, sigma=10.0),
#  KernelParam(size=8, sigma=11.0),
#  KernelParam(size=8, sigma=12.0),
#  KernelParam(size=8, sigma=13.0),
#  KernelParam(size=8, sigma=14.0),
#  KernelParam(size=8, sigma=15.0),
#  KernelParam(size=8, sigma=16.0),
#  KernelParam(size=8, sigma=17.0),
#  KernelParam(size=8, sigma=18.0),
#  KernelParam(size=9, sigma=1.0),
#  KernelParam(size=9, sigma=2.0),
#  KernelParam(size=9, sigma=3.0),
#  KernelParam(size=9, sigma=4.0),
#  KernelParam(size=9, sigma=5.0),
#  KernelParam(size=9, sigma=6.0),
#  KernelParam(size=9, sigma=7.0),
#  KernelParam(size=9, sigma=8.0),
#  KernelParam(size=9, sigma=9.0),
#  KernelParam(size=9, sigma=10.0),
#  KernelParam(size=9, sigma=11.0),
#  KernelParam(size=9, sigma=12.0),
#  KernelParam(size=9, sigma=13.0),
#  KernelParam(size=9, sigma=14.0),
#  KernelParam(size=9, sigma=15.0),
#  KernelParam(size=9, sigma=16.0),
#  KernelParam(size=9, sigma=17.0),
#  KernelParam(size=9, sigma=18.0),
#  KernelParam(size=9, sigma=19.0),
#  KernelParam(size=9, sigma=20.0),
#  KernelParam(size=10, sigma=1.0),
#  KernelParam(size=10, sigma=2.0),
#  KernelParam(size=10, sigma=3.0),
#  KernelParam(size=10, sigma=4.0),
#  KernelParam(size=10, sigma=5.0),
#  KernelParam(size=10, sigma=6.0),
#  KernelParam(size=10, sigma=7.0),
#  KernelParam(size=10, sigma=8.0),
#  KernelParam(size=10, sigma=9.0),
#  KernelParam(size=10, sigma=10.0),
#  KernelParam(size=10, sigma=11.0),
#  KernelParam(size=10, sigma=12.0),
#  KernelParam(size=10, sigma=13.0),
#  KernelParam(size=10, sigma=14.0),
#  KernelParam(size=10, sigma=15.0),
#  KernelParam(size=10, sigma=16.0),
#  KernelParam(size=10, sigma=17.0),
#  KernelParam(size=10, sigma=18.0),
#  KernelParam(size=10, sigma=19.0),
#  KernelParam(size=10, sigma=20.0),
#  KernelParam(size=10, sigma=21.0),
#  KernelParam(size=10, sigma=22.0),
#  KernelParam(size=11, sigma=1.0),
#  KernelParam(size=11, sigma=2.0),
#  KernelParam(size=11, sigma=3.0),
#  KernelParam(size=11, sigma=4.0),
#  KernelParam(size=11, sigma=5.0),
#  KernelParam(size=11, sigma=6.0),
#  KernelParam(size=11, sigma=7.0),
#  KernelParam(size=11, sigma=8.0),
#  KernelParam(size=11, sigma=9.0),
#  KernelParam(size=11, sigma=10.0),
#  KernelParam(size=11, sigma=11.0),
#  KernelParam(size=11, sigma=12.0),
#  KernelParam(size=11, sigma=13.0),
#  KernelParam(size=11, sigma=14.0),
#  KernelParam(size=11, sigma=15.0),
#  KernelParam(size=11, sigma=16.0),
#  KernelParam(size=11, sigma=17.0),
#  KernelParam(size=11, sigma=18.0),
#  KernelParam(size=11, sigma=19.0),
#  KernelParam(size=11, sigma=20.0),
#  KernelParam(size=11, sigma=21.0),
#  KernelParam(size=11, sigma=22.0),
#  KernelParam(size=11, sigma=23.0),
#  KernelParam(size=11, sigma=24.0),
#  KernelParam(size=12, sigma=1.0),
#  KernelParam(size=12, sigma=2.0),
#  KernelParam(size=12, sigma=3.0),
#  KernelParam(size=12, sigma=4.0),
#  KernelParam(size=12, sigma=5.0),
#  KernelParam(size=12, sigma=6.0),
#  KernelParam(size=12, sigma=7.0),
#  KernelParam(size=12, sigma=8.0),
#  KernelParam(size=12, sigma=9.0),
#  KernelParam(size=12, sigma=10.0),
#  KernelParam(size=12, sigma=11.0),
#  KernelParam(size=12, sigma=12.0),
#  KernelParam(size=12, sigma=13.0),
#  KernelParam(size=12, sigma=14.0),
#  KernelParam(size=12, sigma=15.0),
#  KernelParam(size=12, sigma=16.0),
#  KernelParam(size=12, sigma=17.0),
#  KernelParam(size=12, sigma=18.0),
#  KernelParam(size=12, sigma=19.0),
#  KernelParam(size=12, sigma=20.0),
#  KernelParam(size=12, sigma=21.0),
#  KernelParam(size=12, sigma=22.0),
#  KernelParam(size=12, sigma=23.0),
#  KernelParam(size=12, sigma=24.0),
#  KernelParam(size=12, sigma=25.0),
#  KernelParam(size=12, sigma=26.0),
#  KernelParam(size=13, sigma=1.0),
#  KernelParam(size=13, sigma=2.0),
#  KernelParam(size=13, sigma=3.0),
#  KernelParam(size=13, sigma=4.0),
#  KernelParam(size=13, sigma=5.0),
#  KernelParam(size=13, sigma=6.0),
#  KernelParam(size=13, sigma=7.0),
#  KernelParam(size=13, sigma=8.0),
#  KernelParam(size=13, sigma=9.0),
#  KernelParam(size=13, sigma=10.0),
#  KernelParam(size=13, sigma=11.0),
#  KernelParam(size=13, sigma=12.0),
#  KernelParam(size=13, sigma=13.0),
#  KernelParam(size=13, sigma=14.0),
#  KernelParam(size=13, sigma=15.0),
#  KernelParam(size=13, sigma=16.0),
#  KernelParam(size=13, sigma=17.0),
#  KernelParam(size=13, sigma=18.0),
#  KernelParam(size=13, sigma=19.0),
#  KernelParam(size=13, sigma=20.0),
#  KernelParam(size=13, sigma=21.0),
#  KernelParam(size=13, sigma=22.0),
#  KernelParam(size=13, sigma=23.0),
#  KernelParam(size=13, sigma=24.0),
#  KernelParam(size=13, sigma=25.0),
#  KernelParam(size=13, sigma=26.0),
#  KernelParam(size=13, sigma=27.0),
#  KernelParam(size=13, sigma=28.0),
#  KernelParam(size=14, sigma=1.0),
#  KernelParam(size=14, sigma=2.0),
#  KernelParam(size=14, sigma=3.0),
#  KernelParam(size=14, sigma=4.0),
#  KernelParam(size=14, sigma=5.0),
#  KernelParam(size=14, sigma=6.0),
#  KernelParam(size=14, sigma=7.0),
#  KernelParam(size=14, sigma=8.0),
#  KernelParam(size=14, sigma=9.0),
#  KernelParam(size=14, sigma=10.0),
#  KernelParam(size=14, sigma=11.0),
#  KernelParam(size=14, sigma=12.0),
#  KernelParam(size=14, sigma=13.0),
#  KernelParam(size=14, sigma=14.0),
#  KernelParam(size=14, sigma=15.0),
#  KernelParam(size=14, sigma=16.0),
#  KernelParam(size=14, sigma=17.0),
#  KernelParam(size=14, sigma=18.0),
#  KernelParam(size=14, sigma=19.0),
#  KernelParam(size=14, sigma=20.0),
#  KernelParam(size=14, sigma=21.0),
#  KernelParam(size=14, sigma=22.0),
#  KernelParam(size=14, sigma=23.0),
#  KernelParam(size=14, sigma=24.0),
#  KernelParam(size=14, sigma=25.0),
#  KernelParam(size=14, sigma=26.0),
#  KernelParam(size=14, sigma=27.0),
#  KernelParam(size=14, sigma=28.0),
#  KernelParam(size=14, sigma=29.0),
#  KernelParam(size=14, sigma=30.0),
#  KernelParam(size=15, sigma=1.0),
#  KernelParam(size=15, sigma=2.0),
#  KernelParam(size=15, sigma=3.0),
#  KernelParam(size=15, sigma=4.0),
#  KernelParam(size=15, sigma=5.0),
#  KernelParam(size=15, sigma=6.0),
#  KernelParam(size=15, sigma=7.0),
#  KernelParam(size=15, sigma=8.0),
#  KernelParam(size=15, sigma=9.0),
#  KernelParam(size=15, sigma=10.0),
#  KernelParam(size=15, sigma=11.0),
#  KernelParam(size=15, sigma=12.0),
#  KernelParam(size=15, sigma=13.0),
#  KernelParam(size=15, sigma=14.0),
#  KernelParam(size=15, sigma=15.0),
#  KernelParam(size=15, sigma=16.0),
#  KernelParam(size=15, sigma=17.0),
#  KernelParam(size=15, sigma=18.0),
#  KernelParam(size=15, sigma=19.0),
#  KernelParam(size=15, sigma=20.0),
#  KernelParam(size=15, sigma=21.0),
#  KernelParam(size=15, sigma=22.0),
#  KernelParam(size=15, sigma=23.0),
#  KernelParam(size=15, sigma=24.0),
#  KernelParam(size=15, sigma=25.0),
#  KernelParam(size=15, sigma=26.0),
#  KernelParam(size=15, sigma=27.0),
#  KernelParam(size=15, sigma=28.0),
#  KernelParam(size=15, sigma=29.0),
#  KernelParam(size=15, sigma=30.0),
#  KernelParam(size=15, sigma=31.0),
#  KernelParam(size=15, sigma=32.0),
#  KernelParam(size=16, sigma=1.0),
#  KernelParam(size=16, sigma=2.0),
#  KernelParam(size=16, sigma=3.0),
#  KernelParam(size=16, sigma=4.0),
#  KernelParam(size=16, sigma=5.0),
#  KernelParam(size=16, sigma=6.0),
#  KernelParam(size=16, sigma=7.0),
#  KernelParam(size=16, sigma=8.0),
#  KernelParam(size=16, sigma=9.0),
#  KernelParam(size=16, sigma=10.0),
#  KernelParam(size=16, sigma=11.0),
#  KernelParam(size=16, sigma=12.0),
#  KernelParam(size=16, sigma=13.0),
#  KernelParam(size=16, sigma=14.0),
#  KernelParam(size=16, sigma=15.0),
#  KernelParam(size=16, sigma=16.0),
#  KernelParam(size=16, sigma=17.0),
#  KernelParam(size=16, sigma=18.0),
#  KernelParam(size=16, sigma=19.0),
#  KernelParam(size=16, sigma=20.0),
#  KernelParam(size=16, sigma=21.0),
#  KernelParam(size=16, sigma=22.0),
#  KernelParam(size=16, sigma=23.0),
#  KernelParam(size=16, sigma=24.0),
#  KernelParam(size=16, sigma=25.0),
#  KernelParam(size=16, sigma=26.0),
#  KernelParam(size=16, sigma=27.0),
#  KernelParam(size=16, sigma=28.0),
#  KernelParam(size=16, sigma=29.0),
#  KernelParam(size=16, sigma=30.0),
#  KernelParam(size=16, sigma=31.0),
#  KernelParam(size=16, sigma=32.0),
#  KernelParam(size=16, sigma=33.0),
#  KernelParam(size=16, sigma=34.0),
#  KernelParam(size=17, sigma=1.0),
#  KernelParam(size=17, sigma=2.0),
#  KernelParam(size=17, sigma=3.0),
#  KernelParam(size=17, sigma=4.0),
#  KernelParam(size=17, sigma=5.0),
#  KernelParam(size=17, sigma=6.0),
#  KernelParam(size=17, sigma=7.0),
#  KernelParam(size=17, sigma=8.0),
#  KernelParam(size=17, sigma=9.0),
#  KernelParam(size=17, sigma=10.0),
#  KernelParam(size=17, sigma=11.0),
#  KernelParam(size=17, sigma=12.0),
#  KernelParam(size=17, sigma=13.0),
#  KernelParam(size=17, sigma=14.0),
#  KernelParam(size=17, sigma=15.0),
#  KernelParam(size=17, sigma=16.0),
#  KernelParam(size=17, sigma=17.0),
#  KernelParam(size=17, sigma=18.0),
#  KernelParam(size=17, sigma=19.0),
#  KernelParam(size=17, sigma=20.0),
#  KernelParam(size=17, sigma=21.0),
#  KernelParam(size=17, sigma=22.0),
#  KernelParam(size=17, sigma=23.0),
#  KernelParam(size=17, sigma=24.0),
#  KernelParam(size=17, sigma=25.0),
#  KernelParam(size=17, sigma=26.0),
#  KernelParam(size=17, sigma=27.0),
#  KernelParam(size=17, sigma=28.0),
#  KernelParam(size=17, sigma=29.0),
#  KernelParam(size=17, sigma=30.0),
#  KernelParam(size=17, sigma=31.0),
#  KernelParam(size=17, sigma=32.0),
#  KernelParam(size=17, sigma=33.0),
#  KernelParam(size=17, sigma=34.0),
#  KernelParam(size=17, sigma=35.0),
#  KernelParam(size=17, sigma=36.0),
#  KernelParam(size=18, sigma=1.0),
#  KernelParam(size=18, sigma=2.0),
#  KernelParam(size=18, sigma=3.0),
#  KernelParam(size=18, sigma=4.0),
#  KernelParam(size=18, sigma=5.0),
#  KernelParam(size=18, sigma=6.0),
#  KernelParam(size=18, sigma=7.0),
#  KernelParam(size=18, sigma=8.0),
#  KernelParam(size=18, sigma=9.0),
#  KernelParam(size=18, sigma=10.0),
#  KernelParam(size=18, sigma=11.0),
#  KernelParam(size=18, sigma=12.0),
#  KernelParam(size=18, sigma=13.0),
#  KernelParam(size=18, sigma=14.0),
#  KernelParam(size=18, sigma=15.0),
#  KernelParam(size=18, sigma=16.0),
#  KernelParam(size=18, sigma=17.0),
#  KernelParam(size=18, sigma=18.0),
#  KernelParam(size=18, sigma=19.0),
#  KernelParam(size=18, sigma=20.0),
#  KernelParam(size=18, sigma=21.0),
#  KernelParam(size=18, sigma=22.0),
#  KernelParam(size=18, sigma=23.0),
#  KernelParam(size=18, sigma=24.0),
#  KernelParam(size=18, sigma=25.0),
#  KernelParam(size=18, sigma=26.0),
#  KernelParam(size=18, sigma=27.0),
#  KernelParam(size=18, sigma=28.0),
#  KernelParam(size=18, sigma=29.0),
#  KernelParam(size=18, sigma=30.0),
#  KernelParam(size=18, sigma=31.0),
#  KernelParam(size=18, sigma=32.0),
#  KernelParam(size=18, sigma=33.0),
#  KernelParam(size=18, sigma=34.0),
#  KernelParam(size=18, sigma=35.0),
#  KernelParam(size=18, sigma=36.0),
#  KernelParam(size=18, sigma=37.0),
#  KernelParam(size=18, sigma=38.0),
#  KernelParam(size=19, sigma=1.0),
#  KernelParam(size=19, sigma=2.0),
#  KernelParam(size=19, sigma=3.0),
#  KernelParam(size=19, sigma=4.0),
#  KernelParam(size=19, sigma=5.0),
#  KernelParam(size=19, sigma=6.0),
#  KernelParam(size=19, sigma=7.0),
#  KernelParam(size=19, sigma=8.0),
#  KernelParam(size=19, sigma=9.0),
#  KernelParam(size=19, sigma=10.0),
#  KernelParam(size=19, sigma=11.0),
#  KernelParam(size=19, sigma=12.0),
#  KernelParam(size=19, sigma=13.0),
#  KernelParam(size=19, sigma=14.0),
#  KernelParam(size=19, sigma=15.0),
#  KernelParam(size=19, sigma=16.0),
#  KernelParam(size=19, sigma=17.0),
#  KernelParam(size=19, sigma=18.0),
#  KernelParam(size=19, sigma=19.0),
#  KernelParam(size=19, sigma=20.0),
#  KernelParam(size=19, sigma=21.0),
#  KernelParam(size=19, sigma=22.0),
#  KernelParam(size=19, sigma=23.0),
#  KernelParam(size=19, sigma=24.0),
#  KernelParam(size=19, sigma=25.0),
#  KernelParam(size=19, sigma=26.0),
#  KernelParam(size=19, sigma=27.0),
#  KernelParam(size=19, sigma=28.0),
#  KernelParam(size=19, sigma=29.0),
#  KernelParam(size=19, sigma=30.0),
#  KernelParam(size=19, sigma=31.0),
#  KernelParam(size=19, sigma=32.0),
#  KernelParam(size=19, sigma=33.0),
#  KernelParam(size=19, sigma=34.0),
#  KernelParam(size=19, sigma=35.0),
#  KernelParam(size=19, sigma=36.0),
#  KernelParam(size=19, sigma=37.0),
#  KernelParam(size=19, sigma=38.0),
#  KernelParam(size=19, sigma=39.0),
#  KernelParam(size=19, sigma=40.0),
#  KernelParam(size=20, sigma=1.0),
#  KernelParam(size=20, sigma=2.0),
#  KernelParam(size=20, sigma=3.0),
#  KernelParam(size=20, sigma=4.0),
#  KernelParam(size=20, sigma=5.0),
#  KernelParam(size=20, sigma=6.0),
#  KernelParam(size=20, sigma=7.0),
#  KernelParam(size=20, sigma=8.0),
#  KernelParam(size=20, sigma=9.0),
#  KernelParam(size=20, sigma=10.0),
#  KernelParam(size=20, sigma=11.0),
#  KernelParam(size=20, sigma=12.0),
#  KernelParam(size=20, sigma=13.0),
#  KernelParam(size=20, sigma=14.0),
#  KernelParam(size=20, sigma=15.0),
#  KernelParam(size=20, sigma=16.0),
#  KernelParam(size=20, sigma=17.0),
#  KernelParam(size=20, sigma=18.0),
#  KernelParam(size=20, sigma=19.0),
#  KernelParam(size=20, sigma=20.0),
#  KernelParam(size=20, sigma=21.0),
#  KernelParam(size=20, sigma=22.0),
#  KernelParam(size=20, sigma=23.0),
#  KernelParam(size=20, sigma=24.0),
#  KernelParam(size=20, sigma=25.0),
#  KernelParam(size=20, sigma=26.0),
#  KernelParam(size=20, sigma=27.0),
#  KernelParam(size=20, sigma=28.0),
#  KernelParam(size=20, sigma=29.0),
#  KernelParam(size=20, sigma=30.0),
#  KernelParam(size=20, sigma=31.0),
#  KernelParam(size=20, sigma=32.0),
#  KernelParam(size=20, sigma=33.0),
#  KernelParam(size=20, sigma=34.0),
#  KernelParam(size=20, sigma=35.0),
#  KernelParam(size=20, sigma=36.0),
#  KernelParam(size=20, sigma=37.0),
#  KernelParam(size=20, sigma=38.0),
#  KernelParam(size=20, sigma=39.0),
#  KernelParam(size=20, sigma=40.0),
#  KernelParam(size=20, sigma=41.0),
#  KernelParam(size=20, sigma=42.0),
#  KernelParam(size=21, sigma=1.0),
#  KernelParam(size=21, sigma=2.0),
#  KernelParam(size=21, sigma=3.0),
#  KernelParam(size=21, sigma=4.0),
#  KernelParam(size=21, sigma=5.0),
#  KernelParam(size=21, sigma=6.0),
#  KernelParam(size=21, sigma=7.0),
#  KernelParam(size=21, sigma=8.0),
#  KernelParam(size=21, sigma=9.0),
#  KernelParam(size=21, sigma=10.0),
#  KernelParam(size=21, sigma=11.0),
#  KernelParam(size=21, sigma=12.0),
#  KernelParam(size=21, sigma=13.0),
#  KernelParam(size=21, sigma=14.0),
#  KernelParam(size=21, sigma=15.0),
#  KernelParam(size=21, sigma=16.0),
#  KernelParam(size=21, sigma=17.0),
#  KernelParam(size=21, sigma=18.0),
#  KernelParam(size=21, sigma=19.0),
#  KernelParam(size=21, sigma=20.0),
#  KernelParam(size=21, sigma=21.0),
#  KernelParam(size=21, sigma=22.0),
#  KernelParam(size=21, sigma=23.0),
#  KernelParam(size=21, sigma=24.0),
#  KernelParam(size=21, sigma=25.0),
#  KernelParam(size=21, sigma=26.0),
#  KernelParam(size=21, sigma=27.0),
#  KernelParam(size=21, sigma=28.0),
#  KernelParam(size=21, sigma=29.0),
#  KernelParam(size=21, sigma=30.0),
#  KernelParam(size=21, sigma=31.0),
#  KernelParam(size=21, sigma=32.0),
#  KernelParam(size=21, sigma=33.0),
#  KernelParam(size=21, sigma=34.0),
#  KernelParam(size=21, sigma=35.0),
#  KernelParam(size=21, sigma=36.0),
#  KernelParam(size=21, sigma=37.0),
#  KernelParam(size=21, sigma=38.0),
#  KernelParam(size=21, sigma=39.0),
#  KernelParam(size=21, sigma=40.0),
#  KernelParam(size=21, sigma=41.0),
#  KernelParam(size=21, sigma=42.0),
#  KernelParam(size=21, sigma=43.0),
#  KernelParam(size=21, sigma=44.0),
#  KernelParam(size=22, sigma=1.0),
#  KernelParam(size=22, sigma=2.0),
#  KernelParam(size=22, sigma=3.0),
#  KernelParam(size=22, sigma=4.0),
#  KernelParam(size=22, sigma=5.0),
#  KernelParam(size=22, sigma=6.0),
#  KernelParam(size=22, sigma=7.0),
#  KernelParam(size=22, sigma=8.0),
#  KernelParam(size=22, sigma=9.0),
#  KernelParam(size=22, sigma=10.0),
#  KernelParam(size=22, sigma=11.0),
#  KernelParam(size=22, sigma=12.0),
#  KernelParam(size=22, sigma=13.0),
#  KernelParam(size=22, sigma=14.0),
#  KernelParam(size=22, sigma=15.0),
#  KernelParam(size=22, sigma=16.0),
#  KernelParam(size=22, sigma=17.0),
#  KernelParam(size=22, sigma=18.0),
#  KernelParam(size=22, sigma=19.0),
#  KernelParam(size=22, sigma=20.0),
#  KernelParam(size=22, sigma=21.0),
#  KernelParam(size=22, sigma=22.0),
#  KernelParam(size=22, sigma=23.0),
#  KernelParam(size=22, sigma=24.0),
#  KernelParam(size=22, sigma=25.0),
#  KernelParam(size=22, sigma=26.0),
#  KernelParam(size=22, sigma=27.0),
#  KernelParam(size=22, sigma=28.0),
#  KernelParam(size=22, sigma=29.0),
#  KernelParam(size=22, sigma=30.0),
#  KernelParam(size=22, sigma=31.0),
#  KernelParam(size=22, sigma=32.0),
#  KernelParam(size=22, sigma=33.0),
#  KernelParam(size=22, sigma=34.0),
#  KernelParam(size=22, sigma=35.0),
#  KernelParam(size=22, sigma=36.0),
#  KernelParam(size=22, sigma=37.0),
#  KernelParam(size=22, sigma=38.0),
#  KernelParam(size=22, sigma=39.0),
#  KernelParam(size=22, sigma=40.0),
#  KernelParam(size=22, sigma=41.0),
#  KernelParam(size=22, sigma=42.0),
#  KernelParam(size=22, sigma=43.0),
#  KernelParam(size=22, sigma=44.0),
#  KernelParam(size=22, sigma=45.0),
#  KernelParam(size=22, sigma=46.0),
#  KernelParam(size=23, sigma=1.0),
#  KernelParam(size=23, sigma=2.0),
#  KernelParam(size=23, sigma=3.0),
#  KernelParam(size=23, sigma=4.0),
#  KernelParam(size=23, sigma=5.0),
#  KernelParam(size=23, sigma=6.0),
#  KernelParam(size=23, sigma=7.0),
#  KernelParam(size=23, sigma=8.0),
#  KernelParam(size=23, sigma=9.0),
#  KernelParam(size=23, sigma=10.0),
#  KernelParam(size=23, sigma=11.0),
#  KernelParam(size=23, sigma=12.0),
#  KernelParam(size=23, sigma=13.0),
#  KernelParam(size=23, sigma=14.0),
#  KernelParam(size=23, sigma=15.0),
#  KernelParam(size=23, sigma=16.0),
#  KernelParam(size=23, sigma=17.0),
#  KernelParam(size=23, sigma=18.0),
#  KernelParam(size=23, sigma=19.0),
#  KernelParam(size=23, sigma=20.0),
#  KernelParam(size=23, sigma=21.0),
#  KernelParam(size=23, sigma=22.0),
#  KernelParam(size=23, sigma=23.0),
#  KernelParam(size=23, sigma=24.0),
#  KernelParam(size=23, sigma=25.0),
#  KernelParam(size=23, sigma=26.0),
#  KernelParam(size=23, sigma=27.0),
#  KernelParam(size=23, sigma=28.0),
#  KernelParam(size=23, sigma=29.0),
#  KernelParam(size=23, sigma=30.0),
#  KernelParam(size=23, sigma=31.0),
#  KernelParam(size=23, sigma=32.0),
#  KernelParam(size=23, sigma=33.0),
#  KernelParam(size=23, sigma=34.0),
#  KernelParam(size=23, sigma=35.0),
#  KernelParam(size=23, sigma=36.0),
#  KernelParam(size=23, sigma=37.0),
#  KernelParam(size=23, sigma=38.0),
#  KernelParam(size=23, sigma=39.0),
#  KernelParam(size=23, sigma=40.0),
#  KernelParam(size=23, sigma=41.0),
#  KernelParam(size=23, sigma=42.0),
#  KernelParam(size=23, sigma=43.0),
#  KernelParam(size=23, sigma=44.0),
#  KernelParam(size=23, sigma=45.0),
#  KernelParam(size=23, sigma=46.0),
#  KernelParam(size=23, sigma=47.0),
#  KernelParam(size=23, sigma=48.0),
#  KernelParam(size=24, sigma=1.0),
#  KernelParam(size=24, sigma=2.0),
#  KernelParam(size=24, sigma=3.0),
#  KernelParam(size=24, sigma=4.0),
#  KernelParam(size=24, sigma=5.0),
#  KernelParam(size=24, sigma=6.0),
#  KernelParam(size=24, sigma=7.0),
#  KernelParam(size=24, sigma=8.0),
#  KernelParam(size=24, sigma=9.0),
#  KernelParam(size=24, sigma=10.0),
#  KernelParam(size=24, sigma=11.0),
#  KernelParam(size=24, sigma=12.0),
#  KernelParam(size=24, sigma=13.0),
#  KernelParam(size=24, sigma=14.0),
#  KernelParam(size=24, sigma=15.0),
#  KernelParam(size=24, sigma=16.0),
#  KernelParam(size=24, sigma=17.0),
#  KernelParam(size=24, sigma=18.0),
#  KernelParam(size=24, sigma=19.0),
#  KernelParam(size=24, sigma=20.0),
#  KernelParam(size=24, sigma=21.0),
#  KernelParam(size=24, sigma=22.0),
#  KernelParam(size=24, sigma=23.0),
#  KernelParam(size=24, sigma=24.0),
#  KernelParam(size=24, sigma=25.0),
#  KernelParam(size=24, sigma=26.0),
#  KernelParam(size=24, sigma=27.0),
#  KernelParam(size=24, sigma=28.0),
#  KernelParam(size=24, sigma=29.0),
#  KernelParam(size=24, sigma=30.0),
#  KernelParam(size=24, sigma=31.0),
#  KernelParam(size=24, sigma=32.0),
#  KernelParam(size=24, sigma=33.0),
#  KernelParam(size=24, sigma=34.0),
#  KernelParam(size=24, sigma=35.0),
#  KernelParam(size=24, sigma=36.0),
#  KernelParam(size=24, sigma=37.0),
#  KernelParam(size=24, sigma=38.0),
#  KernelParam(size=24, sigma=39.0),
#  KernelParam(size=24, sigma=40.0),
#  KernelParam(size=24, sigma=41.0),
#  KernelParam(size=24, sigma=42.0),
#  KernelParam(size=24, sigma=43.0),
#  KernelParam(size=24, sigma=44.0),
#  KernelParam(size=24, sigma=45.0),
#  KernelParam(size=24, sigma=46.0),
#  KernelParam(size=24, sigma=47.0),
#  KernelParam(size=24, sigma=48.0),
#  KernelParam(size=24, sigma=49.0),
#  KernelParam(size=24, sigma=50.0),
#  KernelParam(size=25, sigma=1.0),
#  KernelParam(size=25, sigma=2.0),
#  KernelParam(size=25, sigma=3.0),
#  KernelParam(size=25, sigma=4.0),
#  KernelParam(size=25, sigma=5.0),
#  KernelParam(size=25, sigma=6.0),
#  KernelParam(size=25, sigma=7.0),
#  KernelParam(size=25, sigma=8.0),
#  KernelParam(size=25, sigma=9.0),
#  KernelParam(size=25, sigma=10.0),
#  KernelParam(size=25, sigma=11.0),
#  KernelParam(size=25, sigma=12.0),
#  KernelParam(size=25, sigma=13.0),
#  KernelParam(size=25, sigma=14.0),
#  KernelParam(size=25, sigma=15.0),
#  KernelParam(size=25, sigma=16.0),
#  KernelParam(size=25, sigma=17.0),
#  KernelParam(size=25, sigma=18.0),
#  KernelParam(size=25, sigma=19.0),
#  KernelParam(size=25, sigma=20.0),
#  KernelParam(size=25, sigma=21.0),
#  KernelParam(size=25, sigma=22.0),
#  KernelParam(size=25, sigma=23.0),
#  KernelParam(size=25, sigma=24.0),
#  KernelParam(size=25, sigma=25.0),
#  KernelParam(size=25, sigma=26.0),
#  KernelParam(size=25, sigma=27.0),
#  KernelParam(size=25, sigma=28.0),
#  KernelParam(size=25, sigma=29.0),
#  KernelParam(size=25, sigma=30.0),
#  KernelParam(size=25, sigma=31.0),
#  KernelParam(size=25, sigma=32.0),
#  KernelParam(size=25, sigma=33.0),
#  KernelParam(size=25, sigma=34.0),
#  KernelParam(size=25, sigma=35.0),
#  KernelParam(size=25, sigma=36.0),
#  KernelParam(size=25, sigma=37.0),
#  KernelParam(size=25, sigma=38.0),
#  KernelParam(size=25, sigma=39.0),
#  KernelParam(size=25, sigma=40.0),
#  KernelParam(size=25, sigma=41.0),
#  KernelParam(size=25, sigma=42.0),
#  KernelParam(size=25, sigma=43.0),
#  KernelParam(size=25, sigma=44.0),
#  KernelParam(size=25, sigma=45.0),
#  KernelParam(size=25, sigma=46.0),
#  KernelParam(size=25, sigma=47.0),
#  KernelParam(size=25, sigma=48.0),
#  KernelParam(size=25, sigma=49.0),
#  KernelParam(size=25, sigma=50.0),
#  KernelParam(size=25, sigma=51.0),
#  KernelParam(size=25, sigma=52.0),
#  KernelParam(size=26, sigma=1.0),
#  KernelParam(size=26, sigma=2.0),
#  KernelParam(size=26, sigma=3.0),
#  KernelParam(size=26, sigma=4.0),
#  KernelParam(size=26, sigma=5.0),
#  KernelParam(size=26, sigma=6.0),
#  KernelParam(size=26, sigma=7.0),
#  KernelParam(size=26, sigma=8.0),
#  KernelParam(size=26, sigma=9.0),
#  KernelParam(size=26, sigma=10.0),
#  KernelParam(size=26, sigma=11.0),
#  KernelParam(size=26, sigma=12.0),
#  KernelParam(size=26, sigma=13.0),
#  KernelParam(size=26, sigma=14.0),
#  KernelParam(size=26, sigma=15.0),
#  KernelParam(size=26, sigma=16.0),
#  KernelParam(size=26, sigma=17.0),
#  KernelParam(size=26, sigma=18.0),
#  KernelParam(size=26, sigma=19.0),
#  KernelParam(size=26, sigma=20.0),
#  KernelParam(size=26, sigma=21.0),
#  KernelParam(size=26, sigma=22.0),
#  KernelParam(size=26, sigma=23.0),
#  KernelParam(size=26, sigma=24.0),
#  KernelParam(size=26, sigma=25.0),
#  KernelParam(size=26, sigma=26.0),
#  KernelParam(size=26, sigma=27.0),
#  KernelParam(size=26, sigma=28.0),
#  KernelParam(size=26, sigma=29.0),
#  KernelParam(size=26, sigma=30.0),
#  KernelParam(size=26, sigma=31.0),
#  KernelParam(size=26, sigma=32.0),
#  KernelParam(size=26, sigma=33.0),
#  KernelParam(size=26, sigma=34.0),
#  KernelParam(size=26, sigma=35.0),
#  KernelParam(size=26, sigma=36.0),
#  KernelParam(size=26, sigma=37.0),
#  KernelParam(size=26, sigma=38.0),
#  KernelParam(size=26, sigma=39.0),
#  KernelParam(size=26, sigma=40.0),
#  KernelParam(size=26, sigma=41.0),
#  KernelParam(size=26, sigma=42.0),
#  KernelParam(size=26, sigma=43.0),
#  KernelParam(size=26, sigma=44.0),
#  KernelParam(size=26, sigma=45.0),
#  KernelParam(size=26, sigma=46.0),
#  KernelParam(size=26, sigma=47.0),
#  KernelParam(size=26, sigma=48.0),
#  KernelParam(size=26, sigma=49.0),
#  KernelParam(size=26, sigma=50.0),
#  KernelParam(size=26, sigma=51.0),
#  KernelParam(size=26, sigma=52.0),
#  KernelParam(size=26, sigma=53.0),
#  KernelParam(size=26, sigma=54.0),
#  KernelParam(size=27, sigma=1.0),
#  KernelParam(size=27, sigma=2.0),
#  KernelParam(size=27, sigma=3.0),
#  KernelParam(size=27, sigma=4.0),
#  KernelParam(size=27, sigma=5.0),
#  KernelParam(size=27, sigma=6.0),
#  KernelParam(size=27, sigma=7.0),
#  KernelParam(size=27, sigma=8.0),
#  KernelParam(size=27, sigma=9.0),
#  KernelParam(size=27, sigma=10.0),
#  KernelParam(size=27, sigma=11.0),
#  KernelParam(size=27, sigma=12.0),
#  KernelParam(size=27, sigma=13.0),
#  KernelParam(size=27, sigma=14.0),
#  KernelParam(size=27, sigma=15.0),
#  KernelParam(size=27, sigma=16.0),
#  KernelParam(size=27, sigma=17.0),
#  KernelParam(size=27, sigma=18.0),
#  KernelParam(size=27, sigma=19.0),
#  KernelParam(size=27, sigma=20.0),
#  KernelParam(size=27, sigma=21.0),
#  KernelParam(size=27, sigma=22.0),
#  KernelParam(size=27, sigma=23.0),
#  KernelParam(size=27, sigma=24.0),
#  KernelParam(size=27, sigma=25.0),
#  KernelParam(size=27, sigma=26.0),
#  KernelParam(size=27, sigma=27.0),
#  KernelParam(size=27, sigma=28.0),
#  KernelParam(size=27, sigma=29.0),
#  KernelParam(size=27, sigma=30.0),
#  KernelParam(size=27, sigma=31.0),
#  KernelParam(size=27, sigma=32.0),
#  KernelParam(size=27, sigma=33.0),
#  KernelParam(size=27, sigma=34.0),
#  KernelParam(size=27, sigma=35.0),
#  KernelParam(size=27, sigma=36.0),
#  KernelParam(size=27, sigma=37.0),
#  KernelParam(size=27, sigma=38.0),
#  KernelParam(size=27, sigma=39.0),
#  KernelParam(size=27, sigma=40.0),
#  KernelParam(size=27, sigma=41.0),
#  KernelParam(size=27, sigma=42.0),
#  KernelParam(size=27, sigma=43.0),
#  KernelParam(size=27, sigma=44.0),
#  KernelParam(size=27, sigma=45.0),
#  KernelParam(size=27, sigma=46.0),
#  KernelParam(size=27, sigma=47.0),
#  KernelParam(size=27, sigma=48.0),
#  KernelParam(size=27, sigma=49.0),
#  KernelParam(size=27, sigma=50.0),
#  KernelParam(size=27, sigma=51.0),
#  KernelParam(size=27, sigma=52.0),
#  KernelParam(size=27, sigma=53.0),
#  KernelParam(size=27, sigma=54.0),
#  KernelParam(size=27, sigma=55.0),
#  KernelParam(size=27, sigma=56.0),
#  KernelParam(size=28, sigma=1.0),
#  KernelParam(size=28, sigma=2.0),
#  KernelParam(size=28, sigma=3.0),
#  KernelParam(size=28, sigma=4.0),
#  KernelParam(size=28, sigma=5.0),
#  KernelParam(size=28, sigma=6.0),
#  KernelParam(size=28, sigma=7.0),
#  KernelParam(size=28, sigma=8.0),
#  KernelParam(size=28, sigma=9.0),
#  KernelParam(size=28, sigma=10.0),
#  KernelParam(size=28, sigma=11.0),
#  KernelParam(size=28, sigma=12.0),
#  KernelParam(size=28, sigma=13.0),
#  KernelParam(size=28, sigma=14.0),
#  KernelParam(size=28, sigma=15.0),
#  KernelParam(size=28, sigma=16.0),
#  KernelParam(size=28, sigma=17.0),
#  KernelParam(size=28, sigma=18.0),
#  KernelParam(size=28, sigma=19.0),
#  KernelParam(size=28, sigma=20.0),
#  KernelParam(size=28, sigma=21.0),
#  KernelParam(size=28, sigma=22.0),
#  KernelParam(size=28, sigma=23.0),
#  KernelParam(size=28, sigma=24.0),
#  KernelParam(size=28, sigma=25.0),
#  KernelParam(size=28, sigma=26.0),
#  KernelParam(size=28, sigma=27.0),
#  KernelParam(size=28, sigma=28.0),
#  KernelParam(size=28, sigma=29.0),
#  KernelParam(size=28, sigma=30.0),
#  KernelParam(size=28, sigma=31.0),
#  KernelParam(size=28, sigma=32.0),
#  KernelParam(size=28, sigma=33.0),
#  KernelParam(size=28, sigma=34.0),
#  KernelParam(size=28, sigma=35.0),
#  KernelParam(size=28, sigma=36.0),
#  KernelParam(size=28, sigma=37.0),
#  KernelParam(size=28, sigma=38.0),
#  KernelParam(size=28, sigma=39.0),
#  KernelParam(size=28, sigma=40.0),
#  KernelParam(size=28, sigma=41.0),
#  KernelParam(size=28, sigma=42.0),
#  KernelParam(size=28, sigma=43.0),
#  KernelParam(size=28, sigma=44.0),
#  KernelParam(size=28, sigma=45.0),
#  KernelParam(size=28, sigma=46.0),
#  KernelParam(size=28, sigma=47.0),
#  KernelParam(size=28, sigma=48.0),
#  KernelParam(size=28, sigma=49.0),
#  KernelParam(size=28, sigma=50.0),
#  KernelParam(size=28, sigma=51.0),
#  KernelParam(size=28, sigma=52.0),
#  KernelParam(size=28, sigma=53.0),
#  KernelParam(size=28, sigma=54.0),
#  KernelParam(size=28, sigma=55.0),
#  KernelParam(size=28, sigma=56.0),
#  KernelParam(size=28, sigma=57.0),
#  KernelParam(size=28, sigma=58.0),
#  KernelParam(size=29, sigma=1.0),
#  KernelParam(size=29, sigma=2.0),
#  KernelParam(size=29, sigma=3.0),
#  KernelParam(size=29, sigma=4.0),
#  KernelParam(size=29, sigma=5.0),
#  KernelParam(size=29, sigma=6.0),
#  KernelParam(size=29, sigma=7.0),
#  KernelParam(size=29, sigma=8.0),
#  KernelParam(size=29, sigma=9.0),
#  KernelParam(size=29, sigma=10.0),
#  KernelParam(size=29, sigma=11.0),
#  KernelParam(size=29, sigma=12.0),
#  KernelParam(size=29, sigma=13.0),
#  KernelParam(size=29, sigma=14.0),
#  KernelParam(size=29, sigma=15.0),
#  KernelParam(size=29, sigma=16.0),
#  KernelParam(size=29, sigma=17.0),
#  KernelParam(size=29, sigma=18.0),
#  KernelParam(size=29, sigma=19.0),
#  KernelParam(size=29, sigma=20.0),
#  KernelParam(size=29, sigma=21.0),
#  KernelParam(size=29, sigma=22.0),
#  KernelParam(size=29, sigma=23.0),
#  KernelParam(size=29, sigma=24.0),
#  KernelParam(size=29, sigma=25.0),
#  KernelParam(size=29, sigma=26.0),
#  KernelParam(size=29, sigma=27.0),
#  KernelParam(size=29, sigma=28.0),
#  KernelParam(size=29, sigma=29.0),
#  KernelParam(size=29, sigma=30.0),
#  KernelParam(size=29, sigma=31.0),
#  KernelParam(size=29, sigma=32.0),
#  KernelParam(size=29, sigma=33.0),
#  KernelParam(size=29, sigma=34.0),
#  KernelParam(size=29, sigma=35.0),
#  KernelParam(size=29, sigma=36.0),
#  KernelParam(size=29, sigma=37.0),
#  KernelParam(size=29, sigma=38.0),
#  KernelParam(size=29, sigma=39.0),
#  KernelParam(size=29, sigma=40.0),
#  KernelParam(size=29, sigma=41.0),
#  KernelParam(size=29, sigma=42.0),
#  KernelParam(size=29, sigma=43.0),
#  KernelParam(size=29, sigma=44.0),
#  KernelParam(size=29, sigma=45.0),
#  KernelParam(size=29, sigma=46.0),
#  KernelParam(size=29, sigma=47.0),
#  KernelParam(size=29, sigma=48.0),
#  KernelParam(size=29, sigma=49.0),
#  KernelParam(size=29, sigma=50.0),
#  KernelParam(size=29, sigma=51.0),
#  KernelParam(size=29, sigma=52.0),
#  KernelParam(size=29, sigma=53.0),
#  KernelParam(size=29, sigma=54.0),
#  KernelParam(size=29, sigma=55.0),
#  KernelParam(size=29, sigma=56.0),
#  KernelParam(size=29, sigma=57.0),
#  KernelParam(size=29, sigma=58.0),
#  KernelParam(size=29, sigma=59.0),
#  KernelParam(size=29, sigma=60.0),
#  KernelParam(size=30, sigma=1.0),
#  KernelParam(size=30, sigma=2.0),
#  KernelParam(size=30, sigma=3.0),
#  KernelParam(size=30, sigma=4.0),
#  KernelParam(size=30, sigma=5.0),
#  KernelParam(size=30, sigma=6.0),
#  KernelParam(size=30, sigma=7.0),
#  KernelParam(size=30, sigma=8.0),
#  KernelParam(size=30, sigma=9.0),
#  KernelParam(size=30, sigma=10.0),
#  KernelParam(size=30, sigma=11.0),
#  KernelParam(size=30, sigma=12.0),
#  KernelParam(size=30, sigma=13.0),
#  KernelParam(size=30, sigma=14.0),
#  KernelParam(size=30, sigma=15.0),
#  KernelParam(size=30, sigma=16.0),
#  KernelParam(size=30, sigma=17.0),
#  KernelParam(size=30, sigma=18.0),
#  KernelParam(size=30, sigma=19.0),
#  KernelParam(size=30, sigma=20.0),
#  KernelParam(size=30, sigma=21.0),
#  KernelParam(size=30, sigma=22.0),
#  KernelParam(size=30, sigma=23.0),
#  KernelParam(size=30, sigma=24.0),
#  KernelParam(size=30, sigma=25.0),
#  KernelParam(size=30, sigma=26.0),
#  KernelParam(size=30, sigma=27.0),
#  KernelParam(size=30, sigma=28.0),
#  KernelParam(size=30, sigma=29.0),
#  KernelParam(size=30, sigma=30.0),
#  KernelParam(size=30, sigma=31.0),
#  KernelParam(size=30, sigma=32.0),
#  KernelParam(size=30, sigma=33.0),
#  KernelParam(size=30, sigma=34.0),
#  KernelParam(size=30, sigma=35.0),
#  KernelParam(size=30, sigma=36.0),
#  KernelParam(size=30, sigma=37.0),
#  KernelParam(size=30, sigma=38.0),
#  KernelParam(size=30, sigma=39.0),
#  KernelParam(size=30, sigma=40.0),
#  KernelParam(size=30, sigma=41.0),
#  KernelParam(size=30, sigma=42.0),
#  KernelParam(size=30, sigma=43.0),
#  KernelParam(size=30, sigma=44.0),
#  KernelParam(size=30, sigma=45.0),
#  KernelParam(size=30, sigma=46.0),
#  KernelParam(size=30, sigma=47.0),
#  KernelParam(size=30, sigma=48.0),
#  KernelParam(size=30, sigma=49.0),
#  KernelParam(size=30, sigma=50.0),
#  KernelParam(size=30, sigma=51.0),
#  KernelParam(size=30, sigma=52.0),
#  KernelParam(size=30, sigma=53.0),
#  KernelParam(size=30, sigma=54.0),
#  KernelParam(size=30, sigma=55.0),
#  KernelParam(size=30, sigma=56.0),
#  KernelParam(size=30, sigma=57.0),
#  KernelParam(size=30, sigma=58.0),
#  KernelParam(size=30, sigma=59.0),
#  KernelParam(size=30, sigma=60.0),
#  KernelParam(size=30, sigma=61.0),
#  KernelParam(size=30, sigma=62.0),
#  KernelParam(size=31, sigma=1.0),
#  KernelParam(size=31, sigma=2.0),
#  KernelParam(size=31, sigma=3.0),
#  KernelParam(size=31, sigma=4.0),
#  KernelParam(size=31, sigma=5.0),
#  KernelParam(size=31, sigma=6.0),
#  KernelParam(size=31, sigma=7.0),
#  KernelParam(size=31, sigma=8.0),
#  KernelParam(size=31, sigma=9.0),
#  KernelParam(size=31, sigma=10.0),
#  KernelParam(size=31, sigma=11.0),
#  KernelParam(size=31, sigma=12.0),
#  KernelParam(size=31, sigma=13.0),
#  KernelParam(size=31, sigma=14.0),
#  KernelParam(size=31, sigma=15.0),
#  KernelParam(size=31, sigma=16.0),
#  KernelParam(size=31, sigma=17.0),
#  KernelParam(size=31, sigma=18.0),
#  KernelParam(size=31, sigma=19.0),
#  KernelParam(size=31, sigma=20.0),
#  ...]

# %%
len(kernel_param)
# Out:
# 14508

# %%
kernel_param[-1]
# Out:
# KernelParam(size=119, sigma=240.0)

# %%
input_data = mi.PipelineInput(
    img_path = img_path,
    filter_intensity=filter_intensity,
    kernel_param=kernel_param,
    agg_type=np.sum
)
model = model_pipeline(is_debug=False)
agg=model.run(input_data=input_data)

#6m 10s

# %%
image = cv2.imread(img_path)
 
resultado_final = agg.map

# Obter a intensidade ao longo das dimensões x e y
intensity = np.stack(resultado_final, axis=0)

# Encontrar o valor máximo por linha (eixo y) e por coluna (eixo x)
max_by_x = intensity.max(axis=0)  # Máximo ao longo da dimensão y (colunas)
max_by_y = intensity.max(axis=1)  # Máximo ao longo da dimensão x (linhas)

# Obter os valores de x e y
x_values = np.arange(intensity.shape[1])
y_values = np.arange(intensity.shape[0])

# Encontrar picos para a curva de intensidade por x e y
prominence_x = 0.15 * max(max_by_x)  # Prominência de 15% do valor máximo
prominence_y = 0.15 * max(max_by_y)  # Prominência de 15% do valor máximo

peaks_x, _ = find_peaks(max_by_x, prominence=prominence_x, height=0.55 * max(max_by_x))
peaks_y, _ = find_peaks(max_by_y, prominence=prominence_y, height=0.55 * max(max_by_y))

# Criar o gráfico
plt.figure(figsize=(12, 6))

# Plotar a curva de intensidade por x
plt.subplot(1, 2, 1)
plt.plot(x_values, max_by_x, color='red')
plt.plot(x_values[peaks_x], max_by_x[peaks_x], 'bo', label='Picos')
plt.title('Intensidade de brilho Máxima por x')
plt.xlabel('Posição x')
plt.ylabel('Intensidade')

# Plotar a curva de intensidade por y
plt.subplot(1, 2, 2)
plt.plot(y_values, max_by_y, color='red')
plt.plot(y_values[peaks_y], max_by_y[peaks_y], 'bo', label='Picos')
plt.title('Intensidade de brilho Máxima por y')
plt.xlabel('Posição y')
plt.ylabel('Intensidade')

plt.tight_layout()
plt.show()

# %%
# Encontrar os pares de coordenadas onde há picos nos dois eixos
# Percorrer o mapa de intensidade para verificar onde os picos de x e y coincidem
peak_coords = [(x, y) for y in peaks_y for x in peaks_x if intensity[y, x] >= 0.55 * intensity.max()]

# Desenhar círculos nas coordenadas dos picos encontrados
for (x, y) in peak_coords:
    center = (int(x), int(y))  # Coordenadas (x, y)
    radius = 5  # Raio do círculo
    color = (0, 0, 255)  # Cor (vermelho em BGR)
    thickness = 2  # Espessura da borda
    cv2.circle(image, center, radius, color, thickness)

# Mostrar a imagem com os círculos
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Imagem com Círculos nos Picos Encontrados')
plt.axis('off')
plt.show()

# %%
# Encontrar os pares de coordenadas onde há picos nos dois eixos
# Percorrer o mapa de intensidade para verificar onde os picos de x e y coincidem
peak_coords = [(x, y) for y in peaks_y for x in peaks_x if intensity[y, x] >= 0.55 * intensity.max()]

peak_coords
# Out:
# [(60, 59)]

# %%
# Desenhar pontos nas coordenadas dos picos encontrados
for (x, y) in peak_coords:
    center = (int(x), int(y))  # Coordenadas (x, y)
    color = (0, 0, 255)  # Cor (vermelho em BGR)
    thickness = -1  # Espessura do ponto, negativo preenche o marcador
    cv2.circle(image, center, 2, color, thickness)  # Desenha um ponto com raio 2

# Mostrar a imagem com os pontos
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Candidatos a estrela')
plt.axis('off')
plt.show()
